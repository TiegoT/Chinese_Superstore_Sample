# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import MinMaxScaler

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('sample_sales.csv')

# %%
df_new = df.drop(['Invoice ID', 'Date', 'Time', 'Tax 5%'], 1)

# %%
df_new = pd.get_dummies(df_new)

# %%
df_date = df[['Date']]

# %%
df_new = pd.concat((df_date,df_new), 1)

# %%
df_new.sort_values('Date').head()
# Out:
#          Date  Unit price  Quantity    Total    cogs  gross margin percentage  \
# 496  1/1/2019       63.22         2  132.762  126.44                 4.761905
# 484  1/1/2019       36.98        10  388.290  369.80                 4.761905
# 567  1/1/2019       65.74         9  621.243  591.66                 4.761905
# 523  1/1/2019       62.87         2  132.027  125.74                 4.761905
# 970  1/1/2019       84.63        10  888.615  846.30                 4.761905
#
#      gross income  Rating  Branch_A  Branch_B  ...  Gender_Male  \
# 496         6.322     8.5         0         0  ...            0
# 484        18.490     7.0         0         0  ...            0
# 567        29.583     7.7         1         0  ...            0
# 523         6.287     5.0         0         0  ...            1
# 970        42.315     9.0         0         1  ...            0
#
#      Product line_Electronic accessories  Product line_Fashion accessories  \
# ...

# %%
df_simple = df_new.sort_values('Date')

# %%
df_simple['Date'] = pd.to_datetime(df_simple['Date'])

# %%
df_simple.columns
# Out:
# Index(['Date', 'Unit price', 'Quantity', 'Total', 'cogs',
#        'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
#        'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
#        'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
#        'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
#        'Product line_Fashion accessories', 'Product line_Food and beverages',
#        'Product line_Health and beauty', 'Product line_Home and lifestyle',
#        'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
#        'Payment_Ewallet'],
#       dtype='object')

# %%
# january days
jan_one = df_simple[(df_simple['Date'].dt.day == 1) & (df_simple['Date'].dt.month == 1)]
jan_two = df_simple[(df_simple['Date'].dt.day == 2) & (df_simple['Date'].dt.month == 1)]
jan_three = df_simple[(df_simple['Date'].dt.day == 3) & (df_simple['Date'].dt.month == 1)]
jan_four = df_simple[(df_simple['Date'].dt.day == 4) & (df_simple['Date'].dt.month == 1)]
jan_five = df_simple[(df_simple['Date'].dt.day == 5) & (df_simple['Date'].dt.month == 1)]
jan_six = df_simple[(df_simple['Date'].dt.day == 6) & (df_simple['Date'].dt.month == 1)]
jan_seven = df_simple[(df_simple['Date'].dt.day == 7) & (df_simple['Date'].dt.month == 1)]
jan_eight = df_simple[(df_simple['Date'].dt.day == 8) & (df_simple['Date'].dt.month == 1)]
jan_nine = df_simple[(df_simple['Date'].dt.day == 9) & (df_simple['Date'].dt.month == 1)]
jan_ten = df_simple[(df_simple['Date'].dt.day == 10) & (df_simple['Date'].dt.month == 1)]
jan_eleven = df_simple[(df_simple['Date'].dt.day == 11) & (df_simple['Date'].dt.month == 1)]
jan_twelve = df_simple[(df_simple['Date'].dt.day == 12) & (df_simple['Date'].dt.month == 1)]
jan_thirteen = df_simple[(df_simple['Date'].dt.day == 13) & (df_simple['Date'].dt.month == 1)]
jan_fourteen = df_simple[(df_simple['Date'].dt.day == 14) & (df_simple['Date'].dt.month == 1)]
jan_fifteen = df_simple[(df_simple['Date'].dt.day == 15) & (df_simple['Date'].dt.month == 1)]
jan_sixteen = df_simple[(df_simple['Date'].dt.day == 16) & (df_simple['Date'].dt.month == 1)]
jan_seventeen = df_simple[(df_simple['Date'].dt.day == 17) & (df_simple['Date'].dt.month == 1)]
jan_eighteen = df_simple[(df_simple['Date'].dt.day == 18) & (df_simple['Date'].dt.month == 1)]
jan_nineteen = df_simple[(df_simple['Date'].dt.day == 19) & (df_simple['Date'].dt.month == 1)]
jan_twenty = df_simple[(df_simple['Date'].dt.day == 20) & (df_simple['Date'].dt.month == 1)]
jan_twenty_one = df_simple[(df_simple['Date'].dt.day == 21) & (df_simple['Date'].dt.month == 1)]
jan_twenty_two = df_simple[(df_simple['Date'].dt.day == 22) & (df_simple['Date'].dt.month == 1)]
jan_twenty_three = df_simple[(df_simple['Date'].dt.day == 23) & (df_simple['Date'].dt.month == 1)]
jan_twenty_four = df_simple[(df_simple['Date'].dt.day == 24) & (df_simple['Date'].dt.month == 1)]
jan_twenty_five = df_simple[(df_simple['Date'].dt.day == 25) & (df_simple['Date'].dt.month == 1)]
jan_twenty_six = df_simple[(df_simple['Date'].dt.day == 26) & (df_simple['Date'].dt.month == 1)]
jan_twenty_seven = df_simple[(df_simple['Date'].dt.day == 27) & (df_simple['Date'].dt.month == 1)]
jan_twenty_eight = df_simple[(df_simple['Date'].dt.day == 28) & (df_simple['Date'].dt.month == 1)]
jan_twenty_nine = df_simple[(df_simple['Date'].dt.day == 29) & (df_simple['Date'].dt.month == 1)]
jan_thirty = df_simple[(df_simple['Date'].dt.day == 30) & (df_simple['Date'].dt.month == 1)]
jan_thirty_one = df_simple[(df_simple['Date'].dt.day == 31) & (df_simple['Date'].dt.month == 1)]

# %%
# sum january days
jan_one = jan_one.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_two = jan_two.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_three = jan_three.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_four = jan_four.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_five = jan_five.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_six = jan_six.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_seven = jan_seven.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_eight = jan_eight.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_nine = jan_nine.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_ten = jan_ten.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_eleven = jan_eleven.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_twelve = jan_twelve.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_thirteen = jan_thirteen.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_fourteen = jan_fourteen.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_fifteen = jan_fifteen.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_sixteen = jan_sixteen.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_seventeen = jan_seventeen.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_eighteen = jan_eighteen.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_nineteen = jan_nineteen.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_twenty = jan_twenty.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_twenty_one = jan_twenty_one.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_twenty_two = jan_twenty_two.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_twenty_three = jan_twenty_three.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_twenty_four = jan_twenty_four.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_twenty_five = jan_twenty_five.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_twenty_six = jan_twenty_six.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_twenty_seven = jan_twenty_seven.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_twenty_eight = jan_twenty_eight.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_twenty_nine = jan_twenty_nine.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_thirty = jan_thirty.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
jan_thirty_one = jan_thirty_one.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()

# %%
jan = jan_one.merge(jan_two, how='outer')
jan = jan.merge(jan_three, how='outer')
jan = jan.merge(jan_four, how='outer')
jan = jan.merge(jan_five, how='outer')
jan = jan.merge(jan_six, how='outer')
jan = jan.merge(jan_seven, how='outer')
jan = jan.merge(jan_eight, how='outer')
jan = jan.merge(jan_nine, how='outer')
jan = jan.merge(jan_ten, how='outer')
jan = jan.merge(jan_eleven, how='outer')
jan = jan.merge(jan_twelve, how='outer')
jan = jan.merge(jan_thirteen, how='outer')
jan = jan.merge(jan_fourteen, how='outer')
jan = jan.merge(jan_fifteen, how='outer')
jan = jan.merge(jan_sixteen, how='outer')
jan = jan.merge(jan_seventeen, how='outer')
jan = jan.merge(jan_eighteen, how='outer')
jan = jan.merge(jan_nineteen, how='outer')
jan = jan.merge(jan_twenty, how='outer')
jan = jan.merge(jan_twenty_one, how='outer')
jan = jan.merge(jan_twenty_two, how='outer')
jan = jan.merge(jan_twenty_three, how='outer')
jan = jan.merge(jan_twenty_four, how='outer')
jan = jan.merge(jan_twenty_five, how='outer')
jan = jan.merge(jan_twenty_six, how='outer')
jan = jan.merge(jan_twenty_seven, how='outer')
jan = jan.merge(jan_twenty_eight, how='outer')
jan = jan.merge(jan_twenty_nine, how='outer')
jan = jan.merge(jan_thirty, how='outer')
jan = jan.merge(jan_thirty_one, how='outer')

# %%
jan_date = jan.drop(['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet'], 1)

# %%
jan_date.head()
# Out:
#         Date  gross income
# 0 2019-01-01      225.9610
# 1 2019-01-02       92.6430
# 2 2019-01-03       98.9585
# 3 2019-01-04       77.3185
# 4 2019-01-05      168.4135

# %%
# february days
feb_one = df_simple[(df_simple['Date'].dt.day == 1) & (df_simple['Date'].dt.month == 2)]
feb_two = df_simple[(df_simple['Date'].dt.day == 2) & (df_simple['Date'].dt.month == 2)]
feb_three = df_simple[(df_simple['Date'].dt.day == 3) & (df_simple['Date'].dt.month == 2)]
feb_four = df_simple[(df_simple['Date'].dt.day == 4) & (df_simple['Date'].dt.month == 2)]
feb_five = df_simple[(df_simple['Date'].dt.day == 5) & (df_simple['Date'].dt.month == 2)]
feb_six = df_simple[(df_simple['Date'].dt.day == 6) & (df_simple['Date'].dt.month == 2)]
feb_seven = df_simple[(df_simple['Date'].dt.day == 7) & (df_simple['Date'].dt.month == 2)]
feb_eight = df_simple[(df_simple['Date'].dt.day == 8) & (df_simple['Date'].dt.month == 2)]
feb_nine = df_simple[(df_simple['Date'].dt.day == 9) & (df_simple['Date'].dt.month == 2)]
feb_ten = df_simple[(df_simple['Date'].dt.day == 10) & (df_simple['Date'].dt.month == 2)]
feb_eleven = df_simple[(df_simple['Date'].dt.day == 11) & (df_simple['Date'].dt.month == 2)]
feb_twelve = df_simple[(df_simple['Date'].dt.day == 12) & (df_simple['Date'].dt.month == 2)]
feb_thirteen = df_simple[(df_simple['Date'].dt.day == 13) & (df_simple['Date'].dt.month == 2)]
feb_fourteen = df_simple[(df_simple['Date'].dt.day == 14) & (df_simple['Date'].dt.month == 2)]
feb_fifteen = df_simple[(df_simple['Date'].dt.day == 15) & (df_simple['Date'].dt.month == 2)]
feb_sixteen = df_simple[(df_simple['Date'].dt.day == 16) & (df_simple['Date'].dt.month == 2)]
feb_seventeen = df_simple[(df_simple['Date'].dt.day == 17) & (df_simple['Date'].dt.month == 2)]
feb_eighteen = df_simple[(df_simple['Date'].dt.day == 18) & (df_simple['Date'].dt.month == 2)]
feb_nineteen = df_simple[(df_simple['Date'].dt.day == 19) & (df_simple['Date'].dt.month == 2)]
feb_twenty = df_simple[(df_simple['Date'].dt.day == 20) & (df_simple['Date'].dt.month == 2)]
feb_twenty_one = df_simple[(df_simple['Date'].dt.day == 21) & (df_simple['Date'].dt.month == 2)]
feb_twenty_two = df_simple[(df_simple['Date'].dt.day == 22) & (df_simple['Date'].dt.month == 2)]
feb_twenty_three = df_simple[(df_simple['Date'].dt.day == 23) & (df_simple['Date'].dt.month == 2)]
feb_twenty_four = df_simple[(df_simple['Date'].dt.day == 24) & (df_simple['Date'].dt.month == 2)]
feb_twenty_five = df_simple[(df_simple['Date'].dt.day == 25) & (df_simple['Date'].dt.month == 2)]
feb_twenty_six = df_simple[(df_simple['Date'].dt.day == 26) & (df_simple['Date'].dt.month == 2)]
feb_twenty_seven = df_simple[(df_simple['Date'].dt.day == 27) & (df_simple['Date'].dt.month == 2)]
feb_twenty_eight = df_simple[(df_simple['Date'].dt.day == 28) & (df_simple['Date'].dt.month == 2)]

# %%
# sum february days
feb_one = feb_one.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_two = feb_two.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_three = feb_three.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_four = feb_four.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_five = feb_five.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_six = feb_six.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_seven = feb_seven.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_eight = feb_eight.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_nine = feb_nine.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_ten = feb_ten.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_eleven = feb_eleven.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_twelve = feb_twelve.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_thirteen = feb_thirteen.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_fourteen = feb_fourteen.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_fifteen = feb_fifteen.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_sixteen = feb_sixteen.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_seventeen = feb_seventeen.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_eighteen = feb_eighteen.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_nineteen = feb_nineteen.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_twenty = feb_twenty.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_twenty_one = feb_twenty_one.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_twenty_two = feb_twenty_two.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_twenty_three = feb_twenty_three.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_twenty_four = feb_twenty_four.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_twenty_five = feb_twenty_five.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_twenty_six = feb_twenty_six.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_twenty_seven = feb_twenty_seven.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
feb_twenty_eight = feb_twenty_eight.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()

# %%
feb = feb_one.merge(feb_two, how='outer')
feb = feb.merge(feb_three, how='outer')
feb = feb.merge(feb_four, how='outer')
feb = feb.merge(feb_five, how='outer')
feb = feb.merge(feb_six, how='outer')
feb = feb.merge(feb_seven, how='outer')
feb = feb.merge(feb_eight, how='outer')
feb = feb.merge(feb_nine, how='outer')
feb = feb.merge(feb_ten, how='outer')
feb = feb.merge(feb_eleven, how='outer')
feb = feb.merge(feb_twelve, how='outer')
feb = feb.merge(feb_thirteen, how='outer')
feb = feb.merge(feb_fourteen, how='outer')
feb = feb.merge(feb_fifteen, how='outer')
feb = feb.merge(feb_sixteen, how='outer')
feb = feb.merge(feb_seventeen, how='outer')
feb = feb.merge(feb_eighteen, how='outer')
feb = feb.merge(feb_nineteen, how='outer')
feb = feb.merge(feb_twenty, how='outer')
feb = feb.merge(feb_twenty_one, how='outer')
feb = feb.merge(feb_twenty_two, how='outer')
feb = feb.merge(feb_twenty_three, how='outer')
feb = feb.merge(feb_twenty_four, how='outer')
feb = feb.merge(feb_twenty_five, how='outer')
feb = feb.merge(feb_twenty_six, how='outer')
feb = feb.merge(feb_twenty_seven, how='outer')
feb = feb.merge(feb_twenty_eight, how='outer')

# %%
feb_date = feb.drop(['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet'], 1)

# %%
months = jan.copy()
months = months.merge(feb, how='outer')

# %%
# march days
march_one = df_simple[(df_simple['Date'].dt.day == 1) & (df_simple['Date'].dt.month == 3)]
march_two = df_simple[(df_simple['Date'].dt.day == 2) & (df_simple['Date'].dt.month == 3)]
march_three = df_simple[(df_simple['Date'].dt.day == 3) & (df_simple['Date'].dt.month == 3)]
march_four = df_simple[(df_simple['Date'].dt.day == 4) & (df_simple['Date'].dt.month == 3)]
march_five = df_simple[(df_simple['Date'].dt.day == 5) & (df_simple['Date'].dt.month == 3)]
march_six = df_simple[(df_simple['Date'].dt.day == 6) & (df_simple['Date'].dt.month == 3)]
march_seven = df_simple[(df_simple['Date'].dt.day == 7) & (df_simple['Date'].dt.month == 3)]
march_eight = df_simple[(df_simple['Date'].dt.day == 8) & (df_simple['Date'].dt.month == 3)]
march_nine = df_simple[(df_simple['Date'].dt.day == 9) & (df_simple['Date'].dt.month == 3)]
march_ten = df_simple[(df_simple['Date'].dt.day == 10) & (df_simple['Date'].dt.month == 3)]
march_eleven = df_simple[(df_simple['Date'].dt.day == 11) & (df_simple['Date'].dt.month == 3)]
march_twelve = df_simple[(df_simple['Date'].dt.day == 12) & (df_simple['Date'].dt.month == 3)]
march_thirteen = df_simple[(df_simple['Date'].dt.day == 13) & (df_simple['Date'].dt.month == 3)]
march_fourteen = df_simple[(df_simple['Date'].dt.day == 14) & (df_simple['Date'].dt.month == 3)]
march_fifteen = df_simple[(df_simple['Date'].dt.day == 15) & (df_simple['Date'].dt.month == 3)]
march_sixteen = df_simple[(df_simple['Date'].dt.day == 16) & (df_simple['Date'].dt.month == 3)]
march_seventeen = df_simple[(df_simple['Date'].dt.day == 17) & (df_simple['Date'].dt.month == 3)]
march_eighteen = df_simple[(df_simple['Date'].dt.day == 18) & (df_simple['Date'].dt.month == 3)]
march_nineteen = df_simple[(df_simple['Date'].dt.day == 19) & (df_simple['Date'].dt.month == 3)]
march_twenty = df_simple[(df_simple['Date'].dt.day == 20) & (df_simple['Date'].dt.month == 3)]
march_twenty_one = df_simple[(df_simple['Date'].dt.day == 21) & (df_simple['Date'].dt.month == 3)]
march_twenty_two = df_simple[(df_simple['Date'].dt.day == 22) & (df_simple['Date'].dt.month == 3)]
march_twenty_three = df_simple[(df_simple['Date'].dt.day == 23) & (df_simple['Date'].dt.month == 3)]
march_twenty_four = df_simple[(df_simple['Date'].dt.day == 24) & (df_simple['Date'].dt.month == 3)]
march_twenty_five = df_simple[(df_simple['Date'].dt.day == 25) & (df_simple['Date'].dt.month == 3)]
march_twenty_six = df_simple[(df_simple['Date'].dt.day == 26) & (df_simple['Date'].dt.month == 3)]
march_twenty_seven = df_simple[(df_simple['Date'].dt.day == 27) & (df_simple['Date'].dt.month == 3)]
march_twenty_eight = df_simple[(df_simple['Date'].dt.day == 28) & (df_simple['Date'].dt.month == 3)]
march_twenty_nine = df_simple[(df_simple['Date'].dt.day == 29) & (df_simple['Date'].dt.month == 3)]
march_thirty = df_simple[(df_simple['Date'].dt.day == 30) & (df_simple['Date'].dt.month == 3)]
march_thirty_one = df_simple[(df_simple['Date'].dt.day == 31) & (df_simple['Date'].dt.month == 3)]

# %%
# sum february days
march_one = march_one.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_two = march_two.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_three = march_three.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_four = march_four.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_five = march_five.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_six = march_six.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_seven = march_seven.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_eight = march_eight.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_nine = march_nine.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_ten = march_ten.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_eleven = march_eleven.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_twelve = march_twelve.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_thirteen = march_thirteen.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_fourteen = march_fourteen.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_fifteen = march_fifteen.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_sixteen = march_sixteen.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_seventeen = march_seventeen.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_eighteen = march_eighteen.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_nineteen = march_nineteen.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_twenty = march_twenty.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_twenty_one = march_twenty_one.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_twenty_two = march_twenty_two.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_twenty_three = march_twenty_three.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_twenty_four = march_twenty_four.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_twenty_five = march_twenty_five.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_twenty_six = march_twenty_six.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_twenty_seven = march_twenty_seven.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_twenty_eight = march_twenty_eight.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_twenty_nine = march_twenty_nine.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_thirty = march_thirty.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()
march_thirty_one = march_thirty_one.groupby('Date')[['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'gross income', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet']].sum().reset_index()

# %%
march = march_one.merge(march_two, how='outer')
march = march.merge(march_three, how='outer')
march = march.merge(march_four, how='outer')
march = march.merge(march_five, how='outer')
march = march.merge(march_six, how='outer')
march = march.merge(march_seven, how='outer')
march = march.merge(march_eight, how='outer')
march = march.merge(march_nine, how='outer')
march = march.merge(march_ten, how='outer')
march = march.merge(march_eleven, how='outer')
march = march.merge(march_twelve, how='outer')
march = march.merge(march_thirteen, how='outer')
march = march.merge(march_fourteen, how='outer')
march = march.merge(march_fifteen, how='outer')
march = march.merge(march_sixteen, how='outer')
march = march.merge(march_seventeen, how='outer')
march = march.merge(march_eighteen, how='outer')
march = march.merge(march_nineteen, how='outer')
march = march.merge(march_twenty, how='outer')
march = march.merge(march_twenty_one, how='outer')
march = march.merge(march_twenty_two, how='outer')
march = march.merge(march_twenty_three, how='outer')
march = march.merge(march_twenty_four, how='outer')
march = march.merge(march_twenty_five, how='outer')
march = march.merge(march_twenty_six, how='outer')
march = march.merge(march_twenty_seven, how='outer')
march = march.merge(march_twenty_eight, how='outer')
march = march.merge(march_twenty_nine, how='outer')
march = march.merge(march_thirty, how='outer')
march = march.merge(march_thirty_one, how='outer')

# %%
march_date = march.drop(['Unit price', 'Quantity', 'Total', 'cogs',
       'gross margin percentage', 'Rating', 'Branch_A',
       'Branch_B', 'Branch_C', 'City_Mandalay', 'City_Naypyitaw',
       'City_Yangon', 'Customer type_Member', 'Customer type_Normal',
       'Gender_Female', 'Gender_Male', 'Product line_Electronic accessories',
       'Product line_Fashion accessories', 'Product line_Food and beverages',
       'Product line_Health and beauty', 'Product line_Home and lifestyle',
       'Product line_Sports and travel', 'Payment_Cash', 'Payment_Credit card',
       'Payment_Ewallet'], 1)

# %%
months = months.merge(march, how='outer')

# %%
plt.plot(months.Date, months['gross income'])
plt.show()

# %%
months.head()
# Out:
#         Date  Unit price  Quantity      Total     cogs  \
# 0 2019-01-01      659.95        81  4745.1810  4519.22
# 1 2019-01-02      357.08        48  1945.5030  1852.86
# 2 2019-01-03      475.66        37  2078.1285  1979.17
# 3 2019-01-04      310.46        32  1623.6885  1546.37
# 4 2019-01-05      739.64        55  3536.6835  3368.27
#
#    gross margin percentage  gross income  Rating  Branch_A  Branch_B  ...  \
# 0                57.142857      225.9610    79.0         5         3  ...
# 1                38.095238       92.6430    48.4         2         4  ...
# 2                38.095238       98.9585    64.9         3         3  ...
# 3                28.571429       77.3185    39.1         2         3  ...
# 4                57.142857      168.4135    89.2         5         3  ...
#
#    Gender_Male  Product line_Electronic accessories  \
# 0            4                                    3
# 1            6                                    1
# ...

# %%
# add previous sales to the next row
df_diff = months.copy()

df_diff['prev_sales'] = df_diff['gross income'].shift(1)

#drop the null values and calculate the difference
df_diff = df_diff.dropna()
df_diff['diff'] = (df_diff['gross income'] - df_diff['prev_sales'])

df_diff.head()
# Out:
#         Date  Unit price  Quantity      Total     cogs  \
# 1 2019-01-02      357.08        48  1945.5030  1852.86
# 2 2019-01-03      475.66        37  2078.1285  1979.17
# 3 2019-01-04      310.46        32  1623.6885  1546.37
# 4 2019-01-05      739.64        55  3536.6835  3368.27
# 5 2019-01-06      536.16        52  3614.2050  3442.10
#
#    gross margin percentage  gross income  Rating  Branch_A  Branch_B  ...  \
# 1                38.095238       92.6430    48.4         2         4  ...
# 2                38.095238       98.9585    64.9         3         3  ...
# 3                28.571429       77.3185    39.1         2         3  ...
# 4                57.142857      168.4135    89.2         5         3  ...
# 5                42.857143      172.1050    73.6         5         2  ...
#
#    Product line_Fashion accessories  Product line_Food and beverages  \
# 1                                 2                                1
# ...

# %%
df_supervised = df_diff.drop(['prev_sales'], axis=1)

# adding lags
for inc in range(1,12):
    field_name = 'lag_' + str(inc)
    df_supervised[field_name] = df_supervised['diff'].shift(inc)
    
# drop null values
df_supervised = df_supervised.dropna().reset_index(drop=True)

# %%
# train = months
# train['Date'] = pd.to_datetime(months['Date'])
# train['Date'] = train['Date'].astype('datetime64[D]').astype(int)
# test = march
# test['Date'] = pd.to_datetime(march['Date'])
# test['Date'] = test['Date'].astype('datetime64[D]').astype(int)

# X_train = train['Date'].values
# y_train = train['gross income']
# X_test = test['Date'].values
# y_test = test['gross income']

X = df_supervised.drop('gross income', 1)
X['Date'] = pd.to_datetime(months['Date'])
X['Date'] = X['Date'].astype('datetime64[D]').astype(int)
y = df_supervised['gross income']

# %%
# apply Min Max Scaler 
scaler = MinMaxScaler(feature_range=(-1, 1))
X_scaled = scaler.fit_transform(X)

# %%
# linear regression
model = LinearRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.39, shuffle=True)

# %%
X_test.shape
# Out:
# (31, 38)

# %%
model.fit(X_train, y_train)
pred_train = model.predict(X_train)

# %%
b = float(model.intercept_)

# %%
coeff = pd.DataFrame(model.coef_, X.columns, columns=['Coefficient'])

# %%
print("Intercept:", b)
# Out:
# Intercept: 200.19725

# %%
coeff
# Out:
#                                       Coefficient
# Date                                -1.968558e-15
# Unit price                           8.659740e-14
# Quantity                             1.591668e-13
# Total                                7.785487e+01
# cogs                                 7.785487e+01
# gross margin percentage              1.172862e-14
# Rating                              -7.489280e-14
# Branch_A                            -4.379859e-14
# Branch_B                            -8.775205e-14
# Branch_C                            -4.090472e-15
# City_Mandalay                       -2.380321e-14
# City_Naypyitaw                       5.630566e-14
# City_Yangon                          3.613746e-14
# Customer type_Member                 2.054847e-14
# Customer type_Normal                -8.396857e-14
# Gender_Female                       -9.053595e-14
# Gender_Male                         -3.977321e-14
# Product line_Electronic accessories -6.061783e-14
# ...

# %%
print(mean_squared_error(y_train, pred_train))
# Out:
# 7.059413345922154e-27

# %%
X_train.shape
# Out:
# (46, 38)

# %%
pred_test = model.predict(X_test)

# %%
print(mean_squared_error(y_test, pred_test))
# Out:
# 1.654185334571317e-26

# %%
# we want to plot the train and test response variables as a continuous line
train_plot = y_train.append(pd.Series(y_test.iloc[:], index=['1552003200000000000']))

# %%
#plt.plot(np.arange(len(y)), model.predict(X_scaled), label='Predicted')
plt.plot(np.arange(len(train_plot)), train_plot, label='Training')
plt.plot(np.arange(len(y_test))+len(y_train), y_test, label='Testing')
plt.legend()

plt.show()

# %%
plt.plot(np.arange(len(y)), model.predict(X_scaled), label='Predicted')
plt.plot(np.arange(len(train_plot)), train_plot, label='Training')
plt.plot(np.arange(len(y_test))+len(y_train), y_test, label='Testing')
plt.legend()

plt.show()

# %%
# ARIMA
# LSTM
